# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
import time

# %%
df=pd.DataFrame(columns=['serial no','Registration Number','Date of Grant','Name Factory Address','IS NO','Product','Status','Valid Upto','Models deleted from scope','Brand','View Models'])

# %%
for param in range(1,11):
    url="https://www.crsbis.in/BIS/Lims_registration.do?hmode=getLimsData&regNo=NA==&prodCat=&models="
    driver= webdriver.Chrome("/home/abhishek/Desktop/Web/chromedriver")
    driver.get(url)
    time.sleep(10)
    soup= BeautifulSoup(driver.page_source,'html5lib')
    driver.close()
    rows = soup.find("table").find("tbody").find_all("tr")
    for row in rows:
        s_no=row.find_all('td')[0].get_text().replace(" ","").replace("\n","")
        Registration_Number=row.find_all('td')[1].get_text().replace(" ","").replace("\n","")
        Date=row.find_all('td')[2].get_text().replace(" ","").replace("\n","")
        Date1=row.find_all('td')[3].get_text().replace(" ","").replace("\n","")
        Date2=row.find_all('td')[4].get_text().replace(" ","").replace("\n","")
        Date3=row.find_all('td')[5].get_text().replace(" ","").replace("\n","")
        Date4=row.find_all('td')[6].get_text().replace(" ","").replace("\n","")
        Date5=row.find_all('td')[7].get_text().replace(" ","").replace("\n","")
        Date6=row.find_all('td')[8].get_text().replace(" ","").replace("\n","")
        Date7=row.find_all('td')[9].get_text().replace(" ","").replace("\n","")
        Date8=row.find_all('td')[10].get_text().replace(" ","").replace("\n","")
        df=df.append({'serial no':s_no,'Registration Number':Registration_Number,'Date of Grant':Date,'Name Factory Address':Date1,'IS NO':Date2,'Product':Date3,'Status':Date4,'Valid Upto':Date5,'Models deleted from scope':Date6,'Brand':Date7,'View Models':Date8},ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-140c5808ab80> in <module>
#      18         Date6=row.find_all('td')[8].get_text().replace(" ","").replace("\n","")
#      19         Date7=row.find_all('td')[9].get_text().replace(" ","").replace("\n","")
# ---> 20         Date8=row.find_all('td')[10].get_text().replace(" ","").replace("\n","")
#      21         df=df.append({'serial no':s_no,'Registration Number':Registration_Number,'Date of Grant':Date,'Name Factory Address':Date1,'IS NO':Date2,'Product':Date3,'Status':Date4,'Valid Upto':Date5,'Models deleted from scope':Date6,'Brand':Date7,'View Models':Date8},ignore_index=True)
#      22
#
# IndexError: list index out of range

# %%
df
# Out:
#      serial no Registration Number Date of Grant  \
# 0            1          R-41147907   26-Dec-2019
# 1            2          R-41085979   06-Apr-2018
# 2            3          R-41126209   20-May-2019
# 3            4          R-41069965   18-Jul-2017
# 4            5          R-41157309   26-May-2020
# ...        ...                 ...           ...
# 9006      9007          R-41044032   08-Jul-2016
# 9007      9008          R-41043958   08-Jul-2016
# 9008      9009          R-41044229   11-Jul-2016
# 9009      9010          R-41044172   11-Jul-2016
# 9010      9011          R-41044482   14-Jul-2016
#
#                                    Name Factory Address  \
# 0     JabilCircuitDeMexicoSDeRLDeCVGUADALUPE420,GUAD...
# 1     CELESTICA(DONGGUAN-SSL)TECHNOLOGYLTDNORTHERNAR...
# 2     KontronCanadaInc.4555AMBROISE-LAFORTUNE,BOISBR...
# 3     3DSYSTEMSCORPORATION333THREEDSYSTEMCIRROCKHILL...
# 4     WuhanWeiMaTechnologyCo,.Ltd.ROOMA-F-508,CHUANG...
# ...                                                 ...
# 9006  ShenzhenMassPowerElectronicLimitedNO.437,HEDON...
# 9007  ShenzhenKunxingTechnologyCo.,Ltd.ROOM402,403,4...
# 9008  ZhonghanScience&TechCo.LtdBUILDING9,SECTIONB,J...
# 9009  ShenzhenGospellDigitalTechnologyCoLtdEASTOFTHE...
# 9010  DongguanSunstrongElectricalAndMechanicalCo.,Lt...
#
#                                     IS NO  \
# 0     IS13252(Part1):2010/IEC60950-1:2005
# 1     IS13252(Part1):2010/IEC60950-1:2005
# 2     IS13252(Part1):2010/IEC60950-1:2005
# 3     IS13252(Part1):2010/IEC60950-1:2005
# 4     IS13252(PART1):2010/IEC60950-1:2005
# ...                                   ...
# 9006  IS13252(Part1):2010/IEC60950-1:2005
# 9007  IS13252(Part1):2010/IEC60950-1:2005
# 9008  IS13252(Part1):2010/IEC60950-1:2005
# 9009  IS13252(Part1):2010/IEC60950-1:2005
# 9010  IS13252(Part1):2010/IEC60950-1:2005
#
#                                                 Product     Status  \
# 0     2NodeApplianceServer(AUTOMATICDATAPROCESSINGMA...  Operative
# 1         2UNVMeStorage(AutomaticDataProcessingMachine)  Operative
# 2          2URMComputer(AutomaticDataProcessingMachine)  Operative
# 3                                             3DScanner    Expired
# 4                                   3DScanner(Scanners)  Operative
# ...                                                 ...        ...
# 9006                       PowerAdaptorsforITEquipments  Operative
# 9007                       PowerAdaptorsforITEquipments    Expired
# 9008                       PowerAdaptorsforITEquipments  Operative
# 9009                       PowerAdaptorsforITEquipments  Operative
# 9010                       PowerAdaptorsforITEquipments  Operative
#
#        Valid Upto Models deleted from scope                      Brand  \
# 0     25-Dec-2021                         -                      JABIL
# 1     05-Apr-2020                         -                  Celestica
# 2     19-May-2021                         -                    KONTRON
# 3     17-Jul-2019                         -                      Sense
# 4     25-May-2022                         -  WuhanWeimaTechnologyCoLtd
# ...           ...                       ...                        ...
# 9006  07-Jul-2022                         -                  Masspower
# 9007  07-Jul-2018                         -                      LeEco
# 9008  10-Jul-2023                         -                     HUAWEI
# 9009  10-Jul-2022                         -             RUCKUSWIRELESS
# 9010  13-Jul-2022                         -                        SIL
#
#                                             View Models
# 0                                         J-M2216A-2D-1
# 1                                               X2024-M
# 2     SYMKLOUD(followingmodelsincludedon12July2019)M...
# 3                                              Sense-RS
# 4                                  USOL,USOL-DUO,USOL-X
# ...                                                 ...
# 9006  NBS24J055260D5(followingmodelsincludedon08Sep2...
# 9007                                           EQ-24BIN
# 9008                                          POE85-56A
# 9009  740-64214-001(followingmodelsincludedon28July2...
# 9010  SSA-5WVI-09IN060010,SSA-5WVI-09IN060020,SSA-5W...
#
# [9011 rows x 11 columns]

# %%
df.to_csv('data.csv', index=False)

# %%
df.shape
# Out:
# (9011, 11)
